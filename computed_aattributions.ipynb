# %%
import pandas as pd
from statsmodels.stats.multitest import fdrcorrection 
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Data

# %%
male_df = pd.read_csv('male_df_occ.csv',index_col=0)
male_df_wrong = pd.read_csv('male_df_occ_wrong.csv',index_col=0)

# %%
male_df
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 0       -0.161183     -0.186112      -0.029893      -0.134153
# 1        0.334201      0.514510       0.320840       0.376098
# 2       -0.134646     -0.107560      -0.043464      -0.017074
# 3       -0.252429     -0.296777      -0.048076      -0.181815
# 4       -0.196767     -0.237034       0.002010      -0.159240
# ..            ...           ...            ...            ...
# 207     -0.266895     -0.301184      -0.184214      -0.134257
# 208      0.574503      0.558883       0.490617       0.523116
# 209      0.038293     -0.136966       0.068114      -0.079011
# 210      0.712942      0.621784       0.271299       0.289629
# 211     -0.411636     -0.342926      -0.245813      -0.258804
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 0            -0.217939          -0.105542       0.011601      -0.161337
# 1             0.431332           0.216536       0.145110       0.278704
# 2            -0.104819          -0.072065      -0.029654       0.019953
# 3            -0.223763          -0.198276      -0.024222      -0.067008
# 4            -0.216705          -0.205040      -0.114651      -0.062365
# ..                 ...                ...            ...            ...
# 207          -0.330050          -0.249132      -0.140950      -0.137779
# 208           0.563260           0.483421       0.199424       0.406746
# 209          -0.113908           0.016694      -0.018037      -0.072155
# 210           0.447929           0.427063       0.150036       0.278165
# 211          -0.389680          -0.141888      -0.020405      -0.112425
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_1_2  Vermis_3  \
# 0             0.060225          -0.107676  ...    0.014785 -0.096826
# 1             0.028166          -0.004893  ...    0.112547  0.065504
# 2            -0.066507          -0.107085  ...    0.085185  0.135969
# 3            -0.058650          -0.171786  ...   -0.078847 -0.048181
# 4            -0.169677          -0.028399  ...    0.063116  0.034061
# ..                 ...                ...  ...         ...       ...
# 207           0.060856          -0.204436  ...    0.068468  0.098563
# 208           0.121080           0.334430  ...    0.060935  0.088383
# 209          -0.050173          -0.107930  ...    0.023640 -0.056502
# 210           0.347000           0.207986  ...    0.191264  0.171012
# 211          -0.014423          -0.062636  ...   -0.094483  0.070262
#
#      Vermis_4_5  Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  \
# 0     -0.140513 -0.230760 -0.284890 -0.253655 -0.200221  -0.196882  46.0
# 1      0.134872  0.323375  0.475299  0.380688  0.354846   0.204026  43.0
# 2     -0.011357 -0.085136 -0.154838 -0.137434 -0.117086   0.001109  67.0
# 3     -0.099069 -0.208520 -0.365133 -0.378858 -0.340330  -0.164167  60.0
# 4     -0.027437 -0.234338 -0.255082 -0.256802 -0.224104  -0.107108  62.0
# ..          ...       ...       ...       ...       ...        ...   ...
# 207   -0.107872 -0.259809 -0.354726 -0.327630 -0.274275  -0.276345  49.0
# 208    0.330529  0.500504  0.651027  0.606114  0.558177   0.438856  46.0
# 209   -0.008658 -0.142092 -0.172927 -0.156731 -0.159477  -0.116310  57.0
# 210    0.325145  0.404091  0.598857  0.417493  0.460101   0.365181  46.0
# 211   -0.073336 -0.237983 -0.363817 -0.396863 -0.318269   0.029308  50.0
#
#      memory
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
# ..      ...
# 207       0
# 208       1
# 209       0
# 210       1
# 211       0
#
# [212 rows x 118 columns]

# %%
male_df['sex'] = 1

# %%
female_df = pd.read_csv('female_df_occ.csv',index_col=0)
female_df_wrong = pd.read_csv('female_df_occ_wrong.csv',index_col=0)

# %%
female_df['sex']=0

# %%
female_df
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 0       -0.064588     -0.071586      -0.030646      -0.027438
# 1       -0.185712     -0.278652      -0.255499      -0.267088
# 2       -0.085050     -0.061219       0.095939      -0.139740
# 3        0.048920     -0.035198       0.047295      -0.015762
# 4       -0.078544     -0.108015      -0.019833      -0.037605
# ..            ...           ...            ...            ...
# 254     -0.065327     -0.190085      -0.041882      -0.035778
# 255      0.680978      0.659264       0.619297       0.477615
# 256     -0.301069     -0.163452      -0.173167      -0.134390
# 257      0.473773      0.523857       0.323385       0.449808
# 258     -0.332392     -0.297695      -0.268806      -0.204134
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 0            -0.068508          -0.064792       0.000118      -0.040572
# 1            -0.214138          -0.121137      -0.020661      -0.282704
# 2            -0.205578          -0.030745       0.271298      -0.021778
# 3            -0.017701          -0.031639      -0.017360      -0.010200
# 4            -0.084176          -0.064698       0.104923      -0.011241
# ..                 ...                ...            ...            ...
# 254          -0.117844          -0.109745      -0.015063      -0.152760
# 255           0.633111           0.400876       0.278089       0.466838
# 256          -0.285450          -0.158282      -0.066077      -0.170833
# 257           0.333965           0.444588       0.109381       0.227385
# 258          -0.326121          -0.304689      -0.016615      -0.029489
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 0            -0.043166           0.043905  ...  0.048183    0.029238
# 1            -0.160760           0.002818  ... -0.056575   -0.135342
# 2             0.017321          -0.026599  ...  0.110084   -0.027066
# 3            -0.000170           0.002434  ...  0.104249    0.038957
# 4            -0.019544          -0.093449  ... -0.024279    0.048047
# ..                 ...                ...  ...       ...         ...
# 254          -0.040281          -0.017698  ...  0.103571   -0.104253
# 255           0.267740           0.287796  ...  0.224975    0.133826
# 256          -0.023104          -0.160156  ...  0.098816    0.031574
# 257           0.244440           0.112315  ... -0.062458    0.324805
# 258          -0.096766          -0.208797  ... -0.019016   -0.272547
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  memory  sex
# 0   -0.073641 -0.109332 -0.103306 -0.093276  -0.063736  60.0       0    0
# 1   -0.264766 -0.357611 -0.310518 -0.298695  -0.207756  62.0       0    0
# 2   -0.053283 -0.261821 -0.273013 -0.263802  -0.122423  47.0       0    0
# 3   -0.019207 -0.048025 -0.046968 -0.044636  -0.026713  60.0       0    0
# 4   -0.147365 -0.183676 -0.148108 -0.094847  -0.125083  63.0       0    0
# ..        ...       ...       ...       ...        ...   ...     ...  ...
# 254 -0.153343 -0.196882 -0.160430 -0.127093  -0.085236  69.0       0    0
# 255  0.474866  0.689350  0.704447  0.435626   0.432975  56.0       1    0
# 256 -0.147015 -0.266407 -0.191559 -0.083457  -0.095907  65.0       0    0
# 257  0.403142  0.573464  0.556159  0.413771   0.406321  61.0       1    0
# 258 -0.330407 -0.391595 -0.402309 -0.352663  -0.191351  63.0       0    0
#
# [259 rows x 119 columns]

# %% [markdown]
# ## Performing 1 sample t-test

# %%
all_df = pd.concat([male_df,female_df],ignore_index=True)

# %%
all_df
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 0       -0.161183     -0.186112      -0.029893      -0.134153
# 1        0.334201      0.514510       0.320840       0.376098
# 2       -0.134646     -0.107560      -0.043464      -0.017074
# 3       -0.252429     -0.296777      -0.048076      -0.181815
# 4       -0.196767     -0.237034       0.002010      -0.159240
# ..            ...           ...            ...            ...
# 466     -0.065327     -0.190085      -0.041882      -0.035778
# 467      0.680978      0.659264       0.619297       0.477615
# 468     -0.301069     -0.163452      -0.173167      -0.134390
# 469      0.473773      0.523857       0.323385       0.449808
# 470     -0.332392     -0.297695      -0.268806      -0.204134
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 0            -0.217939          -0.105542       0.011601      -0.161337
# 1             0.431332           0.216536       0.145110       0.278704
# 2            -0.104819          -0.072065      -0.029654       0.019953
# 3            -0.223763          -0.198276      -0.024222      -0.067008
# 4            -0.216705          -0.205040      -0.114651      -0.062365
# ..                 ...                ...            ...            ...
# 466          -0.117844          -0.109745      -0.015063      -0.152760
# 467           0.633111           0.400876       0.278089       0.466838
# 468          -0.285450          -0.158282      -0.066077      -0.170833
# 469           0.333965           0.444588       0.109381       0.227385
# 470          -0.326121          -0.304689      -0.016615      -0.029489
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 0             0.060225          -0.107676  ... -0.096826   -0.140513
# 1             0.028166          -0.004893  ...  0.065504    0.134872
# 2            -0.066507          -0.107085  ...  0.135969   -0.011357
# 3            -0.058650          -0.171786  ... -0.048181   -0.099069
# 4            -0.169677          -0.028399  ...  0.034061   -0.027437
# ..                 ...                ...  ...       ...         ...
# 466          -0.040281          -0.017698  ...  0.103571   -0.104253
# 467           0.267740           0.287796  ...  0.224975    0.133826
# 468          -0.023104          -0.160156  ...  0.098816    0.031574
# 469           0.244440           0.112315  ... -0.062458    0.324805
# 470          -0.096766          -0.208797  ... -0.019016   -0.272547
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  memory  sex
# 0   -0.230760 -0.284890 -0.253655 -0.200221  -0.196882  46.0       0    1
# 1    0.323375  0.475299  0.380688  0.354846   0.204026  43.0       1    1
# 2   -0.085136 -0.154838 -0.137434 -0.117086   0.001109  67.0       0    1
# 3   -0.208520 -0.365133 -0.378858 -0.340330  -0.164167  60.0       0    1
# 4   -0.234338 -0.255082 -0.256802 -0.224104  -0.107108  62.0       0    1
# ..        ...       ...       ...       ...        ...   ...     ...  ...
# 466 -0.153343 -0.196882 -0.160430 -0.127093  -0.085236  69.0       0    0
# 467  0.474866  0.689350  0.704447  0.435626   0.432975  56.0       1    0
# 468 -0.147015 -0.266407 -0.191559 -0.083457  -0.095907  65.0       0    0
# 469  0.403142  0.573464  0.556159  0.413771   0.406321  61.0       1    0
# 470 -0.330407 -0.391595 -0.402309 -0.352663  -0.191351  63.0       0    0
#
# [471 rows x 119 columns]

# %% [markdown]
# #### changing the position of the columns on the dataframe

# %%
header = all_df.columns.tolist()[:]

# %%
header[-2],header[-1] = header[-1],header[-2]

# %%
all_df = all_df[header]

# %%
low_memory = all_df[all_df['memory'] == 0]
high_memory = all_df[all_df['memory'] == 1]

# %% [markdown]
# #### ttest

# %%
from scipy.stats import ttest_1samp

# %% [markdown]
# ##### Flipping sign on low memory

# %%
low_memory = low_memory * -1
low_memory['sex'] = low_memory['sex'] * -1
low_memory['memory'] = low_memory['memory'] * -1
low_memory['age'] = low_memory['age'] * -1 
all_df = pd.concat([high_memory,low_memory],ignore_index=True)

# %%
tval,pval = ttest_1samp(low_memory.iloc[:,:-3].values.tolist(),popmean=0,axis=0)

# %%
region_tvals = dict(sorted({header[i]:pval[i] for i in range(len(tval)) if pval[i] < 0.05}.items(),key = lambda x:x[1]))

# %%
region_tvals
# Out:
# {'Caudate_R': 5.55206983992777e-161,
#  'Frontal_Inf_Oper_R': 1.3551797497891234e-149,
#  'Vermis_7': 3.534333421993806e-133,
#  'Fusiform_L': 4.240615370996846e-130,
#  'Cerebelum_6_R': 1.64953710876354e-129,
#  'Cerebelum_Crus1_R': 3.36738545639358e-129,
#  'Vermis_8': 1.4127381197607803e-126,
#  'Cerebelum_4_5_L': 1.5282690903747596e-126,
#  'Rectus_L': 1.2818662510199795e-122,
#  'Lingual_L': 1.3221086941880725e-122,
#  'Cerebelum_7b_L': 1.760949380544701e-122,
#  'Cerebelum_Crus1_L': 5.628338580306558e-122,
#  'Temporal_Mid_R': 2.6606516425153186e-121,
#  'Fusiform_R': 4.043469929833158e-121,
#  'Vermis_9': 6.205171758503162e-120,
#  'Cerebelum_Crus2_L': 8.77430873192191e-120,
#  'Cerebelum_3_R': 2.7743947834415295e-118,
#  'Occipital_Inf_R': 6.3215581302589394e-117,
#  'Cerebelum_8_L': 8.961823624770238e-117,
#  'Rectus_R': 8.885041591506133e-112,
#  'Vermis_6': 5.899533624220682e-110,
#  'Lingual_R': 3.945158481084954e-109,
#  'Cerebelum_6_L': 8.719788082762424e-109,
#  'Frontal_Sup_Orb_L': 9.934689167713927e-109,
#  'Frontal_Med_Orb_R': 1.4612680616625367e-100,
#  'Putamen_R': 7.457141770996831e-95,
#  'Precentral_R': 3.040853179278761e-91,
#  'Postcentral_L': 3.2127043791748136e-90,
#  'Temporal_Mid_L': 4.087044784955918e-90,
#  'Calcarine_L': 2.007440918253282e-86,
#  'Cingulum_Mid_R': 8.178922585521989e-84,
#  'Frontal_Med_Orb_L': 9.376627472154705e-84,
#  'Cerebelum_9_R': 1.1305765046759285e-83,
#  'Cingulum_Post_L': 5.735854484580412e-81,
#  'Occipital_Mid_L': 7.588627128396768e-81,
#  'Cerebelum_4_5_R': 2.0911291525036243e-79,
#  'Calcarine_R': 5.547497437956659e-79,
#  'Precuneus_L': 3.5943997657241423e-78,
#  'Angular_L': 1.0528056051787931e-77,
#  'Vermis_10': 3.1183486173235007e-75,
#  'Pallidum_L': 2.125667601396061e-73,
#  'Frontal_Inf_Tri_L': 3.4997641040640257e-71,
#  'Postcentral_R': 1.3871677506671909e-69,
#  'Cerebelum_Crus2_R': 1.8216926273350465e-67,
#  'Insula_R': 2.7052101159996026e-67,
#  'Heschl_R': 2.8748320927002836e-66,
#  'ParaHippocampal_R': 4.2994741478602793e-66,
#  'Frontal_Sup_Orb_R': 4.406389408178529e-65,
#  'Frontal_Sup_R': 3.407595895075647e-64,
#  'Cerebelum_8_R': 1.3078859680329254e-61,
#  'Thalamus_R': 5.4432610199588796e-61,
#  'Cuneus_R': 6.279372196017519e-61,
#  'Precentral_L': 1.3275675456636804e-60,
#  'Thalamus_L': 2.2055252478835177e-59,
#  'Frontal_Sup_Medial_L': 2.9213160608038294e-58,
#  'Rolandic_Oper_R': 6.203417214712963e-54,
#  'Frontal_Mid_R': 8.756148631908817e-54,
#  'Cerebelum_3_L': 5.670112258826465e-53,
#  'Cerebelum_7b_R': 1.2819750098643705e-49,
#  'Temporal_Pole_Sup_R': 2.2713834784019002e-48,
#  'Rolandic_Oper_L': 8.69142831827421e-46,
#  'Pallidum_R': 1.9458546813846005e-43,
#  'Parietal_Inf_L': 2.31503628902227e-42,
#  'Olfactory_L': 5.72350468218909e-42,
#  'Temporal_Sup_L': 8.586806113230407e-42,
#  'Occipital_Sup_R': 8.105200285794576e-40,
#  'Supp_Motor_Area_L': 4.0929471771625976e-39,
#  'Occipital_Sup_L': 5.039916671122388e-39,
#  'Temporal_Pole_Mid_R': 1.9689899850599833e-38,
#  'Frontal_Inf_Tri_R': 2.5860251028757522e-37,
#  'Amygdala_R': 2.790208184148312e-36,
#  'Frontal_Inf_Oper_L': 2.6437460795460636e-34,
#  'Cerebelum_9_L': 3.997003796681874e-32,
#  'Insula_L': 4.3929584064550877e-32,
#  'SupraMarginal_L': 5.719206863060392e-31,
#  'Cuneus_L': 6.768393035182419e-31,
#  'SupraMarginal_R': 3.332120379062704e-28,
#  'Cingulum_Ant_R': 2.794374125517079e-27,
#  'Frontal_Sup_L': 4.4098301837631524e-27,
#  'Paracentral_Lobule_L': 1.867295548437419e-26,
#  'Vermis_4_5': 7.2744156884599e-26,
#  'Cerebelum_10_R': 1.4671784437873782e-24,
#  'Olfactory_R': 6.077516729017002e-22,
#  'Parietal_Sup_L': 3.1409297966155235e-19,
#  'Temporal_Inf_R': 5.544538679903317e-19,
#  'Occipital_Inf_L': 6.838390519013078e-18,
#  'Frontal_Sup_Medial_R': 5.001584702932861e-17,
#  'Temporal_Pole_Mid_L': 1.1770008056633747e-16,
#  'Precuneus_R': 1.396048203066216e-15,
#  'Temporal_Inf_L': 2.2164543810589124e-15,
#  'Vermis_3': 3.580926338238639e-14,
#  'Parietal_Sup_R': 3.6525173254317615e-13,
#  'Hippocampus_L': 5.25164062245763e-13,
#  'Amygdala_L': 6.510479788540667e-13,
#  'Occipital_Mid_R': 7.034647754320975e-12,
#  'Frontal_Mid_Orb_R': 1.6830367320940217e-10,
#  'Cingulum_Ant_L': 6.531396303290922e-10,
#  'Heschl_L': 3.156391778188236e-08,
#  'Cerebelum_10_L': 1.0227648674152006e-06,
#  'Cingulum_Post_R': 1.0880095936270064e-06,
#  'Frontal_Mid_Orb_L': 1.825154216690093e-06,
#  'Putamen_L': 3.623236086962806e-06,
#  'Temporal_Sup_R': 6.61790102631394e-06,
#  'ParaHippocampal_L': 6.756228397177836e-06,
#  'Paracentral_Lobule_R': 1.5152245035750954e-05,
#  'Vermis_1_2': 1.7947671734358936e-05,
#  'Frontal_Mid_L': 5.70674081408111e-05,
#  'Caudate_L': 0.00019050269956823605,
#  'Temporal_Pole_Sup_L': 0.0008329191894189462,
#  'Angular_R': 0.0014609400680549265,
#  'Frontal_Inf_Orb_R': 0.011384568156995015}

# %%
fdrcorrection(list(region_tvals.values()),method='negcorr',is_sorted=True)
# Out:
# (array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True, False]),
#  array([3.26088630e-158, 3.97967533e-147, 6.91937708e-131, 6.22658079e-128,
#         1.93763880e-127, 3.29626650e-127, 1.12199411e-124, 1.12199411e-124,
#         7.76511509e-121, 7.76511509e-121, 9.40231772e-121, 2.75473422e-120,
#         1.20205793e-119, 1.69631662e-119, 2.42964758e-118, 3.22087347e-118,
#         9.58517560e-117, 2.06268242e-115, 2.77027911e-115, 2.60921703e-110,
#         1.64998168e-108, 1.05322827e-107, 2.22668524e-107, 2.43121730e-107,
#         3.43297483e-099, 1.68453402e-093, 6.61473459e-090, 6.73896917e-089,
#         8.27736553e-089, 3.93008780e-085, 1.54958406e-082, 1.72098632e-082,
#         2.01217965e-082, 9.90831816e-080, 1.27343243e-079, 3.41160774e-078,
#         8.80594811e-078, 5.55550466e-077, 1.58549296e-076, 4.57873396e-074,
#         3.04503460e-072, 4.89407046e-070, 1.89470353e-068, 2.43166173e-066,
#         3.53076835e-066, 3.67058587e-065, 5.37276963e-065, 5.39165845e-064,
#         4.08444208e-063, 1.53631621e-060, 6.26858790e-060, 7.09240647e-060,
#         1.47116537e-059, 2.39882745e-058, 3.11958334e-057, 6.50614442e-053,
#         9.02233617e-053, 5.74175159e-052, 1.27616927e-048, 2.22341201e-047,
#         8.36839273e-045, 1.84331454e-042, 2.15823131e-041, 5.25246061e-041,
#         7.75888001e-041, 7.21274455e-039, 3.58791440e-038, 4.35306527e-038,
#         1.67600439e-037, 2.16977865e-036, 2.30812325e-035, 2.15659195e-033,
#         3.21582522e-031, 3.48663196e-031, 4.47873408e-030, 5.23061450e-030,
#         2.54162043e-027, 2.10412087e-026, 3.27850243e-026, 1.37089379e-025,
#         5.27465224e-025, 1.05087200e-023, 4.30059758e-021, 2.19613826e-018,
#         3.83113299e-018, 4.67020756e-017, 3.37651832e-016, 7.85551792e-016,
#         9.21278939e-015, 1.44642868e-014, 2.31118511e-013, 2.33176722e-012,
#         3.31659763e-012, 4.06785887e-012, 4.34910093e-011, 1.02968194e-009,
#         3.95471360e-009, 1.89167081e-007, 6.06766147e-006, 6.39018543e-006,
#         1.06135074e-005, 2.08630211e-005, 3.77366878e-005, 3.81550229e-005,
#         8.47556037e-005, 9.94450082e-005, 3.13245692e-004, 1.03599609e-003,
#         4.48804399e-003, 7.80046425e-003, 6.02385235e-002]))

# %% [markdown]
# # Ancova

# %% [markdown]
# ## Ancova for all subjects

# %%
from pingouin import ancova

# %%
low_memory = all_df[all_df['memory'] == 0]
high_memory = all_df[all_df['memory'] == 1]

# %%
low_memory
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 155      0.161183      0.186112       0.029893       0.134153
# 156      0.134646      0.107560       0.043464       0.017074
# 157      0.252429      0.296777       0.048076       0.181815
# 158      0.196767      0.237034      -0.002010       0.159240
# 159      0.113835      0.190987       0.108812       0.156947
# ..            ...           ...            ...            ...
# 466      0.100495      0.145988       0.145558       0.128063
# 467      0.027462      0.067343       0.015589       0.012353
# 468      0.065327      0.190085       0.041882       0.035778
# 469      0.301069      0.163452       0.173167       0.134390
# 470      0.332392      0.297695       0.268806       0.204134
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 155           0.217939           0.105542      -0.011601       0.161337
# 156           0.104819           0.072065       0.029654      -0.019953
# 157           0.223763           0.198276       0.024222       0.067008
# 158           0.216705           0.205040       0.114651       0.062365
# 159           0.150961           0.146021       0.035928       0.077771
# ..                 ...                ...            ...            ...
# 466           0.170839           0.151845       0.141816       0.094171
# 467           0.072871           0.032686       0.017755       0.019376
# 468           0.117844           0.109745       0.015063       0.152760
# 469           0.285450           0.158282       0.066077       0.170833
# 470           0.326121           0.304689       0.016615       0.029489
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 155          -0.060225           0.107676  ...  0.096826    0.140513
# 156           0.066507           0.107085  ... -0.135969    0.011357
# 157           0.058650           0.171786  ...  0.048181    0.099069
# 158           0.169677           0.028399  ... -0.034061    0.027437
# 159           0.061708           0.079091  ...  0.011459   -0.085387
# ..                 ...                ...  ...       ...         ...
# 466           0.046779           0.102219  ...  0.032359    0.098937
# 467           0.008265          -0.020828  ... -0.064242    0.022137
# 468           0.040281           0.017698  ... -0.103571    0.104253
# 469           0.023104           0.160156  ... -0.098816   -0.031574
# 470           0.096766           0.208797  ...  0.019016    0.272547
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  sex  memory
# 155  0.230760  0.284890  0.253655  0.200221   0.196882  46.0    1       0
# 156  0.085136  0.154838  0.137434  0.117086  -0.001109  67.0    1       0
# 157  0.208520  0.365133  0.378858  0.340330   0.164167  60.0    1       0
# 158  0.234338  0.255082  0.256802  0.224104   0.107108  62.0    1       0
# 159  0.150104  0.189232  0.191490  0.128245   0.089270  64.0    1       0
# ..        ...       ...       ...       ...        ...   ...  ...     ...
# 466  0.176984  0.203605  0.198542  0.195455   0.155268  60.0    0       0
# 467  0.053216  0.080560  0.072666  0.068522   0.036722  69.0    0       0
# 468  0.153343  0.196882  0.160430  0.127093   0.085236  69.0    0       0
# 469  0.147015  0.266407  0.191559  0.083457   0.095907  65.0    0       0
# 470  0.330407  0.391595  0.402309  0.352663   0.191351  63.0    0       0
#
# [316 rows x 119 columns]

# %%
high_memory
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 0        0.334201      0.514510       0.320840       0.376098
# 1        0.425416      0.547377       0.256001       0.346658
# 2        0.553045      0.588428       0.172477       0.308134
# 3        0.616630      0.559367       0.391749       0.456717
# 4        0.427061      0.447038       0.208246       0.233009
# ..            ...           ...            ...            ...
# 150      0.393066      0.403804       0.279875       0.318322
# 151      0.632102      0.610511       0.559586       0.172290
# 152      0.465450      0.633619       0.462333       0.211769
# 153      0.680978      0.659264       0.619297       0.477615
# 154      0.473773      0.523857       0.323385       0.449808
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 0             0.431332           0.216536       0.145110       0.278704
# 1             0.441485           0.339309       0.300243       0.328812
# 2             0.401882           0.067699       0.090641       0.156646
# 3             0.508969           0.453472       0.180291       0.482402
# 4             0.241654           0.210094       0.154970       0.079492
# ..                 ...                ...            ...            ...
# 150           0.410243           0.296072       0.215118       0.205895
# 151           0.447386           0.267119       0.138749       0.270806
# 152           0.476545           0.301984       0.204229       0.359671
# 153           0.633111           0.400876       0.278089       0.466838
# 154           0.333965           0.444588       0.109381       0.227385
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 0             0.028166          -0.004893  ...  0.065504    0.134872
# 1             0.332226           0.234156  ... -0.062863    0.256095
# 2            -0.050217           0.179282  ...  0.212704    0.209627
# 3             0.150830           0.370874  ...  0.165991    0.590332
# 4             0.015108           0.128195  ...  0.089283    0.326596
# ..                 ...                ...  ...       ...         ...
# 150           0.265322           0.312898  ...  0.015188    0.143908
# 151           0.245179           0.201818  ... -0.059841    0.094141
# 152           0.110369           0.215732  ...  0.340387    0.397227
# 153           0.267740           0.287796  ...  0.224975    0.133826
# 154           0.244440           0.112315  ... -0.062458    0.324805
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  sex  memory
# 0    0.323375  0.475299  0.380688  0.354846   0.204026  43.0    1       1
# 1    0.359509  0.548496  0.486638  0.371832   0.281075  53.0    1       1
# 2    0.302257  0.358033  0.350219  0.329189   0.404837  44.0    1       1
# 3    0.490302  0.673333  0.608866  0.500664   0.452879  50.0    1       1
# 4    0.573473  0.629516  0.555914  0.568023   0.249896  50.0    1       1
# ..        ...       ...       ...       ...        ...   ...  ...     ...
# 150  0.288880  0.437266  0.415458  0.362864   0.195269  64.0    0       1
# 151  0.403945  0.466290  0.506823  0.431861   0.270164  53.0    0       1
# 152  0.537809  0.630372  0.558588  0.549499   0.432635  49.0    0       1
# 153  0.474866  0.689350  0.704447  0.435626   0.432975  56.0    0       1
# 154  0.403142  0.573464  0.556159  0.413771   0.406321  61.0    0       1
#
# [155 rows x 119 columns]

# %% [markdown]
# ##### Do not flip sign if already did for ttest

# %%
low_memory = low_memory * -1

# %%
low_memory['sex'] = low_memory['sex'] * -1
low_memory['memory'] = low_memory['memory'] * -1
low_memory['age'] = low_memory['age'] * -1

# %%
low_memory

# %% [markdown]
# ##### _

# %%
low_memory
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 155      0.161183      0.186112       0.029893       0.134153
# 156      0.134646      0.107560       0.043464       0.017074
# 157      0.252429      0.296777       0.048076       0.181815
# 158      0.196767      0.237034      -0.002010       0.159240
# 159      0.113835      0.190987       0.108812       0.156947
# ..            ...           ...            ...            ...
# 466      0.100495      0.145988       0.145558       0.128063
# 467      0.027462      0.067343       0.015589       0.012353
# 468      0.065327      0.190085       0.041882       0.035778
# 469      0.301069      0.163452       0.173167       0.134390
# 470      0.332392      0.297695       0.268806       0.204134
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 155           0.217939           0.105542      -0.011601       0.161337
# 156           0.104819           0.072065       0.029654      -0.019953
# 157           0.223763           0.198276       0.024222       0.067008
# 158           0.216705           0.205040       0.114651       0.062365
# 159           0.150961           0.146021       0.035928       0.077771
# ..                 ...                ...            ...            ...
# 466           0.170839           0.151845       0.141816       0.094171
# 467           0.072871           0.032686       0.017755       0.019376
# 468           0.117844           0.109745       0.015063       0.152760
# 469           0.285450           0.158282       0.066077       0.170833
# 470           0.326121           0.304689       0.016615       0.029489
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 155          -0.060225           0.107676  ...  0.096826    0.140513
# 156           0.066507           0.107085  ... -0.135969    0.011357
# 157           0.058650           0.171786  ...  0.048181    0.099069
# 158           0.169677           0.028399  ... -0.034061    0.027437
# 159           0.061708           0.079091  ...  0.011459   -0.085387
# ..                 ...                ...  ...       ...         ...
# 466           0.046779           0.102219  ...  0.032359    0.098937
# 467           0.008265          -0.020828  ... -0.064242    0.022137
# 468           0.040281           0.017698  ... -0.103571    0.104253
# 469           0.023104           0.160156  ... -0.098816   -0.031574
# 470           0.096766           0.208797  ...  0.019016    0.272547
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  sex  memory
# 155  0.230760  0.284890  0.253655  0.200221   0.196882  46.0    1       0
# 156  0.085136  0.154838  0.137434  0.117086  -0.001109  67.0    1       0
# 157  0.208520  0.365133  0.378858  0.340330   0.164167  60.0    1       0
# 158  0.234338  0.255082  0.256802  0.224104   0.107108  62.0    1       0
# 159  0.150104  0.189232  0.191490  0.128245   0.089270  64.0    1       0
# ..        ...       ...       ...       ...        ...   ...  ...     ...
# 466  0.176984  0.203605  0.198542  0.195455   0.155268  60.0    0       0
# 467  0.053216  0.080560  0.072666  0.068522   0.036722  69.0    0       0
# 468  0.153343  0.196882  0.160430  0.127093   0.085236  69.0    0       0
# 469  0.147015  0.266407  0.191559  0.083457   0.095907  65.0    0       0
# 470  0.330407  0.391595  0.402309  0.352663   0.191351  63.0    0       0
#
# [316 rows x 119 columns]

# %%
all_df = pd.concat([high_memory,low_memory],ignore_index=True)

# %%
all_df
# Out:
#      Precentral_L  Precentral_R  Frontal_Sup_L  Frontal_Sup_R  \
# 0        0.334201      0.514510       0.320840       0.376098
# 1        0.425416      0.547377       0.256001       0.346658
# 2        0.553045      0.588428       0.172477       0.308134
# 3        0.616630      0.559367       0.391749       0.456717
# 4        0.427061      0.447038       0.208246       0.233009
# ..            ...           ...            ...            ...
# 466      0.100495      0.145988       0.145558       0.128063
# 467      0.027462      0.067343       0.015589       0.012353
# 468      0.065327      0.190085       0.041882       0.035778
# 469      0.301069      0.163452       0.173167       0.134390
# 470      0.332392      0.297695       0.268806       0.204134
#
#      Frontal_Sup_Orb_L  Frontal_Sup_Orb_R  Frontal_Mid_L  Frontal_Mid_R  \
# 0             0.431332           0.216536       0.145110       0.278704
# 1             0.441485           0.339309       0.300243       0.328812
# 2             0.401882           0.067699       0.090641       0.156646
# 3             0.508969           0.453472       0.180291       0.482402
# 4             0.241654           0.210094       0.154970       0.079492
# ..                 ...                ...            ...            ...
# 466           0.170839           0.151845       0.141816       0.094171
# 467           0.072871           0.032686       0.017755       0.019376
# 468           0.117844           0.109745       0.015063       0.152760
# 469           0.285450           0.158282       0.066077       0.170833
# 470           0.326121           0.304689       0.016615       0.029489
#
#      Frontal_Mid_Orb_L  Frontal_Mid_Orb_R  ...  Vermis_3  Vermis_4_5  \
# 0             0.028166          -0.004893  ...  0.065504    0.134872
# 1             0.332226           0.234156  ... -0.062863    0.256095
# 2            -0.050217           0.179282  ...  0.212704    0.209627
# 3             0.150830           0.370874  ...  0.165991    0.590332
# 4             0.015108           0.128195  ...  0.089283    0.326596
# ..                 ...                ...  ...       ...         ...
# 466           0.046779           0.102219  ...  0.032359    0.098937
# 467           0.008265          -0.020828  ... -0.064242    0.022137
# 468           0.040281           0.017698  ... -0.103571    0.104253
# 469           0.023104           0.160156  ... -0.098816   -0.031574
# 470           0.096766           0.208797  ...  0.019016    0.272547
#
#      Vermis_6  Vermis_7  Vermis_8  Vermis_9  Vermis_10   age  sex  memory
# 0    0.323375  0.475299  0.380688  0.354846   0.204026  43.0    1       1
# 1    0.359509  0.548496  0.486638  0.371832   0.281075  53.0    1       1
# 2    0.302257  0.358033  0.350219  0.329189   0.404837  44.0    1       1
# 3    0.490302  0.673333  0.608866  0.500664   0.452879  50.0    1       1
# 4    0.573473  0.629516  0.555914  0.568023   0.249896  50.0    1       1
# ..        ...       ...       ...       ...        ...   ...  ...     ...
# 466  0.176984  0.203605  0.198542  0.195455   0.155268  60.0    0       0
# 467  0.053216  0.080560  0.072666  0.068522   0.036722  69.0    0       0
# 468  0.153343  0.196882  0.160430  0.127093   0.085236  69.0    0       0
# 469  0.147015  0.266407  0.191559  0.083457   0.095907  65.0    0       0
# 470  0.330407  0.391595  0.402309  0.352663   0.191351  63.0    0       0
#
# [471 rows x 119 columns]

# %%
ancv = ancova(all_df,dv = 'SupraMarginal_L', between = 'memory',covar=['sex','age'])

# %%
ancv
# Out:
#      Source        SS   DF           F         p-unc       np2
# 0    memory  4.491213    1  558.456579  8.601018e-82  0.544593
# 1       sex  0.011820    1    1.469792  2.259915e-01  0.003137
# 2       age  0.047940    1    5.961018  1.499579e-02  0.012604
# 3  Residual  3.755702  467         NaN           NaN       NaN

# %%
ancvs = [ancova(all_df,dv = h, between = 'memory',covar=['sex','age']) for h in header[:-3]]

# %% [markdown]
# #### FDR for memory

# %%
memory_pvals = {header:ancv.loc[[0],['p-unc']].values[0][0] for ancv,header in zip(ancvs,header[:-3])}

# %%
memory_pvals = dict(sorted(memory_pvals.items(),key=lambda x:x[1]))

# %%
memory_pvals
# Out:
# {'Cerebelum_6_R': 4.749348487340436e-133,
#  'Rectus_L': 6.098138671757754e-131,
#  'Cerebelum_Crus1_R': 8.78030092146172e-131,
#  'Fusiform_L': 2.855610744914421e-130,
#  'Fusiform_R': 3.454942367911688e-129,
#  'Cerebelum_4_5_L': 7.228384889281449e-129,
#  'Cerebelum_Crus1_L': 3.7029350420843577e-128,
#  'Lingual_L': 2.158697253433306e-127,
#  'Temporal_Mid_R': 1.1048914979550206e-125,
#  'Occipital_Inf_R': 9.824090342595629e-124,
#  'Cerebelum_7b_L': 8.074979724241919e-123,
#  'Lingual_R': 9.510042956852875e-121,
#  'Cerebelum_3_R': 1.0981675740474874e-120,
#  'Cerebelum_Crus2_L': 2.6837798224538597e-120,
#  'Rectus_R': 6.657162149161768e-120,
#  'Vermis_7': 3.157576884970688e-119,
#  'Frontal_Med_Orb_R': 1.2338228085781563e-118,
#  'Postcentral_L': 2.7425381640665703e-116,
#  'Precentral_R': 3.9620812306902745e-115,
#  'Cerebelum_8_L': 5.442636303404349e-114,
#  'Calcarine_L': 1.6419127092982917e-113,
#  'Temporal_Mid_L': 5.162567003241135e-113,
#  'Vermis_8': 4.901658668653806e-112,
#  'Cingulum_Post_L': 1.6393866354378146e-109,
#  'Cerebelum_6_L': 6.888678684682784e-108,
#  'Vermis_9': 2.799145287084284e-107,
#  'Cingulum_Mid_R': 8.346240177045435e-106,
#  'Precuneus_L': 1.227158079697079e-105,
#  'Precentral_L': 2.817651148244453e-104,
#  'Occipital_Mid_L': 9.47976986295893e-104,
#  'Frontal_Med_Orb_L': 1.185880368757078e-103,
#  'Calcarine_R': 8.404693635607688e-102,
#  'Vermis_6': 8.438772293110364e-102,
#  'Thalamus_L': 6.374198757058754e-100,
#  'Frontal_Sup_Orb_L': 2.215199534876381e-99,
#  'Cerebelum_9_R': 6.001823445983198e-99,
#  'Cuneus_L': 1.2935840544901688e-98,
#  'Amygdala_R': 2.834984168263788e-96,
#  'Pallidum_R': 1.0106862758301756e-94,
#  'Cuneus_R': 4.0162645788167744e-94,
#  'Olfactory_L': 1.750848028957866e-91,
#  'Frontal_Mid_R': 8.945044891910437e-91,
#  'Temporal_Inf_R': 1.8152662065371309e-90,
#  'Paracentral_Lobule_L': 2.663584139211004e-90,
#  'Frontal_Sup_R': 4.262528775319943e-90,
#  'Thalamus_R': 1.420136308570819e-89,
#  'Heschl_R': 1.5154773083217295e-89,
#  'Temporal_Pole_Mid_R': 1.7832708307029676e-88,
#  'Frontal_Sup_Medial_L': 4.109735917747172e-88,
#  'Precuneus_R': 8.210598742332034e-88,
#  'Occipital_Sup_L': 9.398963211047553e-85,
#  'Cerebelum_3_L': 5.601476042994807e-84,
#  'Cerebelum_Crus2_R': 1.0207717874094765e-83,
#  'Frontal_Sup_L': 1.1598497771333894e-83,
#  'Hippocampus_L': 1.7023431500396134e-83,
#  'Parietal_Sup_R': 1.241739447750784e-82,
#  'SupraMarginal_L': 8.601018426553643e-82,
#  'Rolandic_Oper_L': 1.4287825777317519e-81,
#  'Temporal_Inf_L': 2.3010543028718903e-81,
#  'Occipital_Inf_L': 4.014867978161457e-81,
#  'Heschl_L': 6.056324685740304e-81,
#  'Caudate_R': 9.681813099267088e-81,
#  'Frontal_Sup_Medial_R': 1.2713712416409182e-79,
#  'Paracentral_Lobule_R': 1.0829537663190982e-76,
#  'Temporal_Pole_Mid_L': 5.880538454828974e-76,
#  'Cerebelum_7b_R': 1.168842405985365e-75,
#  'Frontal_Mid_L': 1.5330849873954678e-75,
#  'Frontal_Sup_Orb_R': 3.1822019688712086e-74,
#  'Cerebelum_9_L': 4.755024744525039e-74,
#  'Vermis_10': 7.90552021513661e-74,
#  'Parietal_Inf_R': 3.619660515237069e-73,
#  'Frontal_Inf_Oper_L': 1.658209746589055e-72,
#  'Hippocampus_R': 1.8492863129109283e-72,
#  'Cerebelum_8_R': 2.315706850570912e-72,
#  'Supp_Motor_Area_R': 1.7357766532114162e-71,
#  'Parietal_Sup_L': 3.050845834593798e-71,
#  'ParaHippocampal_L': 3.1854818775614757e-71,
#  'Temporal_Pole_Sup_L': 7.690573018319154e-71,
#  'Amygdala_L': 1.4114310672045975e-70,
#  'Caudate_L': 8.38342382756269e-70,
#  'Temporal_Sup_R': 1.3241161694645178e-69,
#  'Occipital_Mid_R': 5.501354735852557e-69,
#  'Putamen_L': 2.6730526930058498e-68,
#  'Cingulum_Post_R': 2.7268343291827086e-68,
#  'Temporal_Sup_L': 2.3577564918664763e-67,
#  'Putamen_R': 2.4191739530028314e-67,
#  'Parietal_Inf_L': 1.6224290478782373e-66,
#  'Rolandic_Oper_R': 1.4295177843644215e-62,
#  'ParaHippocampal_R': 6.806497034976855e-62,
#  'Cingulum_Mid_L': 1.2618636417697415e-61,
#  'Insula_L': 1.4049145672388987e-61,
#  'Angular_R': 5.7475381460838855e-61,
#  'Cerebelum_10_R': 1.4910689860904102e-60,
#  'Postcentral_R': 1.2172885509490237e-59,
#  'Pallidum_L': 2.3213738179322637e-59,
#  'Frontal_Inf_Oper_R': 3.440540475780626e-58,
#  'Frontal_Inf_Orb_L': 4.36305198922721e-58,
#  'Vermis_4_5': 1.1602080043648989e-57,
#  'Cingulum_Ant_R': 4.6176955293796974e-57,
#  'Frontal_Mid_Orb_R': 1.6166246579922618e-56,
#  'Temporal_Pole_Sup_R': 2.1984013772846737e-56,
#  'Olfactory_R': 3.066076008227283e-56,
#  'Frontal_Inf_Orb_R': 5.553078167782021e-54,
#  'Occipital_Sup_R': 7.47545046346176e-54,
#  'Cingulum_Ant_L': 1.1126382880719421e-53,
#  'Frontal_Mid_Orb_L': 6.10334362792936e-53,
#  'Supp_Motor_Area_L': 9.023906448184039e-53,
#  'Insula_R': 2.1239557254202374e-52,
#  'SupraMarginal_R': 3.517315194943611e-51,
#  'Frontal_Inf_Tri_R': 2.091509770287927e-50,
#  'Cerebelum_4_5_R': 2.5911345217502036e-49,
#  'Frontal_Inf_Tri_L': 9.056260002474057e-49,
#  'Angular_L': 1.9859200470561024e-48,
#  'Vermis_3': 3.1095087276230876e-46,
#  'Vermis_1_2': 2.852542034238623e-45,
#  'Cerebelum_10_L': 8.266135851120835e-45}

# %%
correction_pass,mem_pval = fdrcorrection(list(memory_pvals.values()),method='negcorr',is_sorted=True)

# %%
correction_pass
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# #### FDR for sex

# %%
sex_pvals = {header:ancv.loc[[1],['p-unc']].values[0][0] for ancv,header in zip(ancvs,header[:-3])}

# %%
sex_pvals = dict(sorted(sex_pvals.items(),key=lambda x:x[1]))

# %%
sex_pvals
# Out:
# {'Hippocampus_L': 0.0223831125318204,
#  'Cingulum_Post_R': 0.0619515027992886,
#  'Cingulum_Post_L': 0.06474075803652318,
#  'Frontal_Sup_R': 0.06479026207437975,
#  'Temporal_Sup_R': 0.0666736644194701,
#  'Rectus_R': 0.07280166002954258,
#  'Paracentral_Lobule_L': 0.1030431974869834,
#  'Cerebelum_6_L': 0.10857094966991587,
#  'Angular_L': 0.11442410919348461,
#  'Supp_Motor_Area_R': 0.12188817905874258,
#  'Cuneus_R': 0.14140258970162983,
#  'Caudate_R': 0.1444252520465546,
#  'Cuneus_L': 0.15185551702676325,
#  'Lingual_R': 0.15261276121383555,
#  'Cingulum_Ant_L': 0.16949599330067258,
#  'Temporal_Inf_L': 0.1830074031736422,
#  'Cerebelum_Crus1_L': 0.1868214386830741,
#  'Vermis_7': 0.19632664162468202,
#  'Occipital_Inf_L': 0.1985704567624296,
#  'Cerebelum_6_R': 0.20781314675991938,
#  'Frontal_Sup_Medial_L': 0.20929178227855513,
#  'Cerebelum_10_R': 0.21497335190724468,
#  'Cerebelum_3_R': 0.22460161927582775,
#  'Cerebelum_Crus2_R': 0.22527194954838875,
#  'SupraMarginal_L': 0.22599153873427982,
#  'Frontal_Inf_Oper_L': 0.23694438563754747,
#  'Temporal_Pole_Mid_R': 0.24166588250205576,
#  'Cerebelum_4_5_L': 0.25299546595287636,
#  'Cerebelum_7b_L': 0.2564833788658434,
#  'Rectus_L': 0.2702038748565601,
#  'ParaHippocampal_L': 0.2741418068754449,
#  'Calcarine_L': 0.27633983430194725,
#  'Parietal_Inf_L': 0.28283631142515603,
#  'Temporal_Sup_L': 0.2938578258265749,
#  'Olfactory_L': 0.29864016023343254,
#  'Parietal_Sup_L': 0.2990999102805203,
#  'Cerebelum_3_L': 0.3003557195196502,
#  'Parietal_Inf_R': 0.3030690179664279,
#  'Rolandic_Oper_R': 0.307224942177042,
#  'Heschl_R': 0.30881953505180165,
#  'Frontal_Sup_L': 0.31791423008437003,
#  'Vermis_8': 0.3217532032828271,
#  'Amygdala_R': 0.3219444914847005,
#  'Amygdala_L': 0.333998784630409,
#  'Temporal_Inf_R': 0.3346267270548636,
#  'Cerebelum_8_R': 0.33965567529521223,
#  'Cerebelum_Crus2_L': 0.340306193897001,
#  'Caudate_L': 0.3482954309685332,
#  'Thalamus_L': 0.368616597086846,
#  'Cingulum_Mid_L': 0.3805651284692463,
#  'Fusiform_L': 0.38064973173424743,
#  'Calcarine_R': 0.38168381703989385,
#  'SupraMarginal_R': 0.40325377181133804,
#  'Precentral_L': 0.40395897600050257,
#  'Frontal_Inf_Tri_L': 0.4135210689281339,
#  'Vermis_6': 0.44849174348398846,
#  'Frontal_Inf_Orb_L': 0.45421885940768636,
#  'Fusiform_R': 0.46099621190915485,
#  'Cerebelum_10_L': 0.4611612566620099,
#  'Lingual_L': 0.4692439117262379,
#  'Cingulum_Mid_R': 0.4712513624010475,
#  'Pallidum_R': 0.47533798779303416,
#  'Frontal_Sup_Orb_L': 0.4760639646487016,
#  'Frontal_Med_Orb_L': 0.4926004076191872,
#  'Vermis_9': 0.4942723364315873,
#  'Supp_Motor_Area_L': 0.4966147059108902,
#  'Frontal_Mid_R': 0.5126541762428596,
#  'Vermis_4_5': 0.5153057117307385,
#  'Temporal_Pole_Sup_L': 0.516871514099578,
#  'Cerebelum_Crus1_R': 0.5211428702652516,
#  'Occipital_Sup_R': 0.5334003386676336,
#  'Hippocampus_R': 0.5448863047487151,
#  'Temporal_Mid_R': 0.5544502386890653,
#  'Precentral_R': 0.5586298618350236,
#  'Rolandic_Oper_L': 0.5803956797350599,
#  'Occipital_Sup_L': 0.5809479929332353,
#  'Vermis_3': 0.5814669862174832,
#  'Cerebelum_9_L': 0.5862373738434186,
#  'Occipital_Mid_L': 0.5863553784969706,
#  'Olfactory_R': 0.6047539705802547,
#  'Frontal_Inf_Oper_R': 0.6166921014090416,
#  'Angular_R': 0.6174084896383132,
#  'Frontal_Sup_Orb_R': 0.6193747556471041,
#  'Pallidum_L': 0.6254317593096239,
#  'Temporal_Mid_L': 0.6409727748325489,
#  'Putamen_L': 0.6463314744828756,
#  'Paracentral_Lobule_R': 0.666512774656935,
#  'Frontal_Mid_Orb_L': 0.6707060020773283,
#  'Insula_R': 0.6989244590012933,
#  'Frontal_Mid_Orb_R': 0.7036317619853374,
#  'Frontal_Med_Orb_R': 0.7075082628627111,
#  'Insula_L': 0.7174878799585593,
#  'Cerebelum_7b_R': 0.7182002250900933,
#  'Heschl_L': 0.7321859796313877,
#  'Vermis_1_2': 0.7469133070484231,
#  'Occipital_Inf_R': 0.7472906719883392,
#  'Thalamus_R': 0.7515568041391931,
#  'Temporal_Pole_Sup_R': 0.7574549735990925,
#  'Frontal_Inf_Tri_R': 0.7704933274978055,
#  'Cerebelum_8_L': 0.7780771785331559,
#  'Vermis_10': 0.7888647041286057,
#  'Frontal_Inf_Orb_R': 0.7894688818813762,
#  'Postcentral_R': 0.8446628174913029,
#  'Temporal_Pole_Mid_L': 0.8457749683568268,
#  'Frontal_Mid_L': 0.8502208419520219,
#  'Cingulum_Ant_R': 0.8553932283729386,
#  'Parietal_Sup_R': 0.883291404182068,
#  'Putamen_R': 0.900324401810842,
#  'Postcentral_L': 0.906945465650374,
#  'ParaHippocampal_R': 0.9194594060081955,
#  'Frontal_Sup_Medial_R': 0.9231489935878407,
#  'Cerebelum_4_5_R': 0.9301422358396227,
#  'Precuneus_R': 0.9407216722181458,
#  'Precuneus_L': 0.9674937656147947,
#  'Cerebelum_9_R': 0.9789246442125387,
#  'Occipital_Mid_R': 0.9982943775744885}

# %%
correction_pass_sex, sex_pval = fdrcorrection(list(sex_pvals.values()),method='negcorr',is_sorted=True)

# %%
correction_pass_sex
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False])

# %% [markdown]
# #### FDR for age

# %%
age_pvals = {header:ancv.loc[[2],['p-unc']].values[0][0] for ancv,header in zip(ancvs,header[:-3])}

# %%
age_pvals = dict(sorted(age_pvals.items(),key=lambda x:x[1]))

# %%
age_pvals
# Out:
# {'Cerebelum_Crus1_R': 1.0001418889065259e-20,
#  'Lingual_R': 5.220360796346845e-20,
#  'Lingual_L': 6.11863225132582e-20,
#  'Fusiform_L': 2.787569329969018e-19,
#  'Temporal_Mid_R': 4.224741248344355e-19,
#  'Vermis_9': 1.1004438984762547e-18,
#  'Fusiform_R': 3.4903755349672225e-18,
#  'Cerebelum_4_5_L': 6.177873612438867e-18,
#  'Rectus_L': 3.11475179659503e-16,
#  'Cerebelum_6_R': 3.853989667925716e-15,
#  'Cerebelum_Crus1_L': 1.1044244518033113e-14,
#  'Occipital_Inf_R': 2.3453365106843255e-14,
#  'Vermis_8': 2.558947897446746e-14,
#  'Rectus_R': 3.8177854378214845e-14,
#  'Temporal_Mid_L': 4.0283547889331503e-14,
#  'Vermis_7': 4.452748799625088e-14,
#  'Cerebelum_Crus2_L': 5.3478460250363356e-14,
#  'Cuneus_R': 6.580866528318509e-14,
#  'Cerebelum_3_R': 5.116848315006037e-13,
#  'Temporal_Inf_L': 2.3655035702593645e-12,
#  'Amygdala_R': 3.745877154220595e-12,
#  'Frontal_Med_Orb_R': 1.3263007698214942e-11,
#  'Thalamus_L': 1.3701515722399713e-11,
#  'Cerebelum_Crus2_R': 2.044118926818191e-11,
#  'Thalamus_R': 2.0511582352802155e-10,
#  'Cerebelum_8_L': 2.815843168077499e-10,
#  'Cerebelum_7b_L': 8.138805845486598e-10,
#  'Postcentral_L': 3.745032207325479e-09,
#  'Temporal_Pole_Mid_L': 7.086660406643567e-08,
#  'Precentral_R': 9.606128028818025e-08,
#  'Calcarine_R': 1.0278215247637674e-07,
#  'Cerebelum_6_L': 1.0560264700823512e-07,
#  'Calcarine_L': 1.2741963867470197e-07,
#  'Cerebelum_9_R': 6.87752189625196e-07,
#  'Cingulum_Ant_L': 7.605925454687302e-07,
#  'Vermis_6': 7.765843557549694e-07,
#  'Rolandic_Oper_L': 1.4036939938368212e-06,
#  'ParaHippocampal_L': 1.4983816808746693e-06,
#  'Frontal_Inf_Tri_L': 1.5542806414622007e-06,
#  'Frontal_Mid_L': 1.6947852444297395e-06,
#  'Occipital_Mid_L': 2.0904499731050353e-06,
#  'Cingulum_Mid_R': 2.6693233763124545e-06,
#  'Frontal_Sup_Medial_R': 2.6759954576728027e-06,
#  'Cingulum_Post_L': 3.6124659300363686e-06,
#  'Precuneus_L': 4.3563154671493976e-06,
#  'Frontal_Sup_Orb_L': 1.7598371452266827e-05,
#  'Temporal_Pole_Mid_R': 2.2733657553890322e-05,
#  'Pallidum_R': 2.6900057785980983e-05,
#  'Parietal_Sup_R': 2.9280537196834197e-05,
#  'Precentral_L': 4.298118854320331e-05,
#  'Vermis_1_2': 5.8109232813146286e-05,
#  'Frontal_Med_Orb_L': 6.745211554854717e-05,
#  'Olfactory_R': 8.885807279992182e-05,
#  'Vermis_10': 0.00014745679864595446,
#  'Vermis_3': 0.00020064086046527374,
#  'Cerebelum_3_L': 0.0004800932246167501,
#  'Occipital_Inf_L': 0.0005861676970256933,
#  'Pallidum_L': 0.0010275628461769825,
#  'Frontal_Inf_Oper_R': 0.0017739183532409423,
#  'Frontal_Inf_Orb_L': 0.0019165703526942965,
#  'Hippocampus_R': 0.0021504111130572633,
#  'Temporal_Sup_R': 0.0022768124467678645,
#  'Temporal_Pole_Sup_R': 0.0025469062115095354,
#  'Frontal_Sup_Orb_R': 0.002619435112658777,
#  'Cingulum_Mid_L': 0.005534548470320109,
#  'Supp_Motor_Area_R': 0.009556019004087356,
#  'Frontal_Sup_R': 0.010200596192172886,
#  'Occipital_Sup_L': 0.012994259523738194,
#  'SupraMarginal_L': 0.014995792773524195,
#  'Cingulum_Ant_R': 0.024790013379481952,
#  'Cerebelum_9_L': 0.0251004093658187,
#  'Temporal_Pole_Sup_L': 0.02704120245096702,
#  'Temporal_Inf_R': 0.028625793366934216,
#  'Vermis_4_5': 0.02962751056552829,
#  'Parietal_Inf_R': 0.04150745755349092,
#  'Angular_R': 0.04514360292237639,
#  'Frontal_Mid_Orb_L': 0.04545219834817205,
#  'Cerebelum_8_R': 0.05046554817465796,
#  'Cerebelum_10_R': 0.05596345178247792,
#  'Heschl_R': 0.06065474824793121,
#  'Heschl_L': 0.07092582884600283,
#  'Frontal_Sup_L': 0.07500280394572204,
#  'Insula_L': 0.09599354736765428,
#  'SupraMarginal_R': 0.09926485101816584,
#  'Paracentral_Lobule_L': 0.10764135386511915,
#  'Caudate_L': 0.13181651429293825,
#  'Frontal_Inf_Tri_R': 0.13433605817164487,
#  'Parietal_Inf_L': 0.14986471520900987,
#  'Parietal_Sup_L': 0.15639309082928773,
#  'Insula_R': 0.16536625593590548,
#  'Frontal_Mid_R': 0.1681243763083617,
#  'Paracentral_Lobule_R': 0.17823904966940632,
#  'Putamen_L': 0.22096192035671597,
#  'Caudate_R': 0.23134573496652852,
#  'Putamen_R': 0.24979027674341278,
#  'Amygdala_L': 0.26109917072631844,
#  'Cingulum_Post_R': 0.2748178709503191,
#  'Temporal_Sup_L': 0.2965931352349635,
#  'Cuneus_L': 0.38749310955461147,
#  'Rolandic_Oper_R': 0.40995274267724635,
#  'Angular_L': 0.4430273792593248,
#  'Occipital_Mid_R': 0.461447632920186,
#  'Frontal_Mid_Orb_R': 0.5221774336070906,
#  'Olfactory_L': 0.5232567466961797,
#  'Occipital_Sup_R': 0.530927892220417,
#  'Cerebelum_10_L': 0.5496279537716693,
#  'Cerebelum_4_5_R': 0.5925155353072764,
#  'ParaHippocampal_R': 0.6074226427884637,
#  'Frontal_Sup_Medial_L': 0.7090725913816325,
#  'Supp_Motor_Area_L': 0.7246118417375349,
#  'Cerebelum_7b_R': 0.8091576853376117,
#  'Precuneus_R': 0.8413173829281829,
#  'Hippocampus_L': 0.908426144657534,
#  'Postcentral_R': 0.9275963281570796,
#  'Frontal_Inf_Orb_R': 0.9930391026863512,
#  'Frontal_Inf_Oper_L': 0.9951389224855764}

# %%
correction_pass_age, _ = fdrcorrection(list(age_pvals.values()),method='negcorr',is_sorted=True)

# %% [markdown]
# # Plotting the images

# %%
low_memory = all_df['memory'] == 0 #flipped
high_memory = all_df['memory'] == 1

# %% [markdown]
# ### Plots

# %%
from nilearn.image import load_img,resample_img
from nilearn.image import new_img_like 
from nilearn.plotting import plot_stat_map
from matplotlib import pyplot as plt
 
imf = load_img('/trdapps/linux-x86_64/matlab/toolboxes/spm12/tpm/labels_Neuromorphometrics.nii')
aal = load_img('/data/users2/pnadigapusuresh1/Downloads/AAL3/AAL3v1.nii.gz')
aal_resampled = resample_img('/data/users2/pnadigapusuresh1/Downloads/AAL3/aal.nii.gz',target_affine=imf.affine,target_shape=imf.shape)

# %%
cuts = np.array([-45,-40,-30,-20,-10,-5,0,10,15,20,25,30,35,40,45,50])
cuts.resize(16)
cuts = cuts.reshape(4,4)

# %%
df = pd.read_csv('/data/users2/pnadigapusuresh1/Downloads/AAL3/aal.nii.txt',sep=' ',index_col=0,header=None,usecols=[0,1],names=['value','regions'])

# %%
reg_mean_contribution = all_df.mean(axis=0).to_dict()

# %% [markdown]
# #### Low memory plot

# %%
stat_map = np.zeros_like(aal_resampled.get_fdata())

# %%
for index,row in df.iterrows():
    if row['regions'] in region_tvals:
        stat_map[aal_resampled.get_fdata() == index] = region_tvals[row['regions']][0]

# %%
stat_map = new_img_like(aal_resampled,stat_map)

# %%
fig, ax = plt.subplots(4,4,figsize = (10,10))
plt.subplots_adjust(hspace=0.01,left=0,wspace=0.01)

# %%
for i in range(4):
    for j in range(4):
        plot_stat_map(stat_map,aal_resampled,display_mode='z',cut_coords=[cuts[i][j]],figure = fig,axes = ax[i][j],colorbar=False, draw_cross=False,annotate=False,cmap='seismic',vmax= 85.00)

# %%
fig

# %% [markdown]
# #### High memory plot

# %%
stat_map = np.zeros_like(aal_resampled.get_fdata(),dtype=float)

# %%
memory_pvals

# %%
correction_pass

# %%
it = iter(memory_pvals.items())

# %%
m_pvals = [next(it) for i in correction_pass if i==True]
m_pvals = dict(m_pvals)

# %%
for index,row in df.iterrows():
    if row['regions'] in m_pvals:
        stat_map[aal_resampled.get_fdata() == index] = reg_mean_contribution[row['regions']]

# %%
fig, ax = plt.subplots(4,4,figsize = (10,10))
plt.subplots_adjust(hspace=0.01,left=0,wspace=0.01)

# %%
stat_map = new_img_like(aal_resampled,stat_map)

# %%
for i in range(4):
    for j in range(4):
        plot_stat_map(stat_map,aal_resampled,display_mode='z',cut_coords=[cuts[i][j]],figure = fig,axes = ax[i][j],colorbar=False, draw_cross=False,annotate=False,cmap='seismic')

# %%
fig

# %%
sorted(reg_mean_contribution.items(),key = lambda x:x[1])

# %% [markdown]
# #### Age plots

# %%
stat_map = np.zeros_like(aal_resampled.get_fdata(),dtype=float)

# %%
it = iter(age_pvals.items())
a_pvals = [next(it) for i in correction_pass_age if i==True]
a_pvals = dict(a_pvals)

# %%
for index,row in df.iterrows():
    if row['regions'] in a_pvals:
        stat_map[aal_resampled.get_fdata() == index] = reg_mean_contribution[row['regions']]

# %%
fig, ax = plt.subplots(4,4,figsize = (10,10))
plt.subplots_adjust(hspace=0.01,left=0,wspace=0.01)

# %%
stat_map = new_img_like(aal_resampled,stat_map)

# %%
for i in range(4):
    for j in range(4):
        plot_stat_map(stat_map,aal_resampled,display_mode='z',cut_coords=[cuts[i][j]],figure = fig,axes = ax[i][j],colorbar=False, draw_cross=False,annotate=False,cmap='seismic')

# %%
fig
