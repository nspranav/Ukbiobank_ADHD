# %%
import os
import pandas as pd
import numpy as np
from torch.utils.data import Dataset
import nibabel as nib
import torch
from torchvision import transforms
import random
from sklearn.utils import resample

# %%
img_path= '/data/qneuromark/Data/UKBiobank/Data_BIDS/Raw_Data'

# %%
dirs = os.listdir(img_path)

# %%
dirs = np.array(dirs,dtype=int)

# %%
img = nib.load(os.path.join(img_path,str(dirs[1])
                            ,'ses_01/anat/Sm6mwc1pT1.nii.nii'))

# %%
img2 = nib.load(os.path.join(img_path,str(dirs[5])
                            ,'ses_01/anat/Sm6mwc1pT1.nii.nii'))

# %%
img.affine
# Out:
# array([[  -1.5,    0. ,    0. ,   90. ],
#        [   0. ,    1.5,    0. , -126. ],
#        [   0. ,    0. ,    1.5,  -72. ],
#        [   0. ,    0. ,    0. ,    1. ]])

# %%
img2.affine
# Out:
# array([[  -1.5,    0. ,    0. ,   90. ],
#        [   0. ,    1.5,    0. , -126. ],
#        [   0. ,    0. ,    1.5,  -72. ],
#        [   0. ,    0. ,    0. ,    1. ]])

# %%
import nilearn

# %%
from nilearn import *

# %%
from email.mime import image


image.load_img('/trdapps/linux-x86_64/matlab/toolboxes/spm12/tpm/labels_Neuromorphometrics.nii')

# %%
imf = nilearn.image.load_img('/trdapps/linux-x86_64/matlab/toolboxes/spm12/tpm/labels_Neuromorphometrics.nii')

# %%
imf.shape

# %%
with open('attr_1.npy','rb') as f:
    a1 = np.load(f)

# %%
a1 /= 1968

# %%
a1.shape

# %%
a1 = a1.squeeze()

# %%
a1.shape

# %%
a1[a1 > 0.01]

# %%
mask = a1 > 0.01

# %%
mask.shape

# %%
mask

# %%
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        for k in range(img.shape[2]):
            if mask[i,j,k]:
                print(i,j,k)
                break

# %%
img = nib.load(os.path.join(img_path,str(dirs[1])
                            ,'ses_01/anat/Sm6mwc1pT1.nii.nii'))

# %%
img.shape

# %%
img.get_data()[21,68,34]

# %%
imf.get_data()[21,68,34]

# %%
# %pip install xmltodict

# %%
import xmltodict
import json

with open('/trdapps/linux-x86_64/matlab/toolboxes/spm12/tpm/labels_Neuromorphometrics.xml') as f:
    data_dict = xmltodict.parse(f.read())

# %%
data_dict['atlas']['data']

# %%
data_dict['atlas']['data']['label'][0]

# %%
labels = data_dict['atlas']['data']['label']

# %%
len(labels)

# %%
for label in labels:
    print(label)

# %%
for label in labels:
    label = {label['index']:label['name']}

# %%
for label in labels:
    print(label)

# %%
from collections import OrderedDict


l = OrderedDict()
for label in labels:
    l[label['index']] = label['name']

# %%
l

# %%
l['4']

# %%
import json


with open('region_labels.json','w') as f:
    json.dump(l,f,indent=6)

# %%
labels

# %%
labels = []
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        for k in range(img.shape[2]):
            if mask[i,j,k]:
                print(i,j,k)
                r = imf[i,j,k]
                try:
                    labels.append(l[str(int(r))])
                except KeyError:
                    print(r)

# %%
len(labels)

# %%
labels = []
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        for k in range(img.shape[2]):
            if mask[i,j,k]:
                r = imf[i,j,k]
                try:
                    labels.append(l[str(int(r))])
                except KeyError:
                    print(r)

# %%
from collections import Counter

c = Counter(labels)

# %%
for k,e in c:
    print(k,e)

# %%
for k,e in c.items():
    print(k,e)

# %%
c.most_common([10])

# %%
c.most_common(10)

# %%
import numpy as np

# %%
1e-1
